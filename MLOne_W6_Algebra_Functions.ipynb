# %% [markdown]
# <a href="https://colab.research.google.com/github/makikooni/appleDevelopment2324/blob/main/MLOne_W6_Algebra_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook prepared by Xiaowan Yi
#
# For ML One Week 6 Introduction to functions (Diploma in Apple Development at UAL)
#
# Last update: 2023-11-01

# %% [markdown]
# # Welcome 🤩

# %% [markdown]
# In this notebook, we will learn about how to implement functions (in a mathematical sense) including exponential, sigmoid, quadratic, relu, sine, tanh in Python using NumPy.

# %% [markdown]
# Before diving into the implementation, here is a refresher on how you can define a function (in a programming sense) in python.
#
# Note the syntax of using keyword **def** and **return**.
#
# Note the syntax of including indentation before function body and **return**.
#
#
#
# ```
# def TheNameOfMyAwesomeFunction(input):
#
#   [function body here, do some magics on the input]
#
#   return [if the function body is a one liner, you can directly write the one liner here as output]
# ```

# %% [markdown]
# Below is a function that outputs the squared value of an input (a quadratic function).
#
# $F(x) = x^2$

# %%
def square(x):
  return x ** 2

# %% [markdown]
# To use the above defined function:

# %%
out = square(2)
print(out)
# Out:
# 4

# %% [markdown]
# # Importing NumPy 🤩

# %% [markdown]
# Make sure you have run the cell below for importing NumPy and other utility libraries. 🥹

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exponential 🤩

# %% [markdown]
# NumPy just makes our life easier with
#
# ```
# np.exp()
# ```

# %% [markdown]
# What is the output when the input is 0?

# %%
np.exp(0)
# Out:
# 1.0

# %% [markdown]
# (Optional, just for you to see the function graph)
#
# With some help from the library matplotlib, we can plot the function graph by evaluating the function at a set of input values

# %%
#Step 1: generate a set of evenly spaced input values between the range [-5, 5] with an increment of 0.5
x = np.arange(-5.0, 5.0, 0.5)
print(x)
# Out:
# [-5.  -4.5 -4.  -3.5 -3.  -2.5 -2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5
#   2.   2.5  3.   3.5  4.   4.5]

# %%
#Step 2: get the output values of the above defined x values
# bonus from np.exp: it can take a set of numbers (as opposed to one single number) as inputs and return a set of output values respectively
y = np.exp(x)
print(y)
# Out:
# [6.73794700e-03 1.11089965e-02 1.83156389e-02 3.01973834e-02
#  4.97870684e-02 8.20849986e-02 1.35335283e-01 2.23130160e-01
#  3.67879441e-01 6.06530660e-01 1.00000000e+00 1.64872127e+00
#  2.71828183e+00 4.48168907e+00 7.38905610e+00 1.21824940e+01
#  2.00855369e+01 3.31154520e+01 5.45981500e+01 9.00171313e+01]

# %%
#Plot the set of y's (from cells above) against x's (from cells above) using the imported library plt
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Sigmoid 🤩

# %% [markdown]
# Here is the equation of sigmoid function:
#
# $Sigmoid(x) = \frac{1}{1 + e^{-x}} $

# %%
def sigmoid(x):
	return 1.0/(1.0+np.exp(-x))

# %% [markdown]
# Similar to above, we can plot the function graph between the range -10 and 10:

# %%
x = np.arange(-10.0, 10.0, 0.5)
y = sigmoid(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# It may seem that some output values have reached the boundaries of 0 and 1, however if you look into the actual values of y:

# %%
print(y)
# Out:
# [4.53978687e-05 7.48462275e-05 1.23394576e-04 2.03426978e-04
#  3.35350130e-04 5.52778637e-04 9.11051194e-04 1.50118226e-03
#  2.47262316e-03 4.07013772e-03 6.69285092e-03 1.09869426e-02
#  1.79862100e-02 2.93122308e-02 4.74258732e-02 7.58581800e-02
#  1.19202922e-01 1.82425524e-01 2.68941421e-01 3.77540669e-01
#  5.00000000e-01 6.22459331e-01 7.31058579e-01 8.17574476e-01
#  8.80797078e-01 9.24141820e-01 9.52574127e-01 9.70687769e-01
#  9.82013790e-01 9.89013057e-01 9.93307149e-01 9.95929862e-01
#  9.97527377e-01 9.98498818e-01 9.99088949e-01 9.99447221e-01
#  9.99664650e-01 9.99796573e-01 9.99876605e-01 9.99925154e-01]

# %% [markdown]
# It just gets reeeally close to 0 and 1 but not exactly 0 and 1.

# %% [markdown]
# # Relu 🤩

# %% [markdown]
# The [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) function is defined as follows
#
# $\text{relu}(x) = \left\{
#    \begin{array}{rl}
#      x, & \text{if }  x \ge 0 \\
#      0, & \text{otherwise }.
#    \end{array}\right.$

# %% [markdown]
# There are several ways to implement.

# %%
# First way: with help from np.maximum()
def Relu_FirstImpementation(x):
  return np.maximum(0,x)

# %%
x = np.arange(-5.0, 5.0, 0.5)
y = Relu_FirstImpementation(x)
plt.plot(x,y)
plt.show()

# %%
# Second way:
# noodling time: how does this work?
def Relu_SecondImpementation(x):
  return x*(x>0)

# %% [markdown]
# because (x>0) returns 1 if it is true and 0 if it is false

# %%
x = np.arange(-5.0, 5.0, 0.5)
y = Relu_SecondImpementation(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Sine 🤩

# %% [markdown]
# NumPy just makes our life easier with
#
# ```
# np.sin()
# ```

# %%
np.sin(0)
# Out:
# 0.0

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Tanh 🤩

# %% [markdown]
# NumPy just makes our life easier again with
#
# ```
# np.tanh()
# ```

# %%
np.tanh(1.9)
# Out:
# 0.9562374581277391

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = np.tanh(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Exersice 1.
#
# 1. Choose two functions to your liking.
# 2. Define a new function (make sure it has a cool name) that chains the selected two funcitons together.
# 3. To be more specific, the new function should take an input x, run it through the first funciton and then the second function:
# output = function2(function1(x))
#
# 4. Plot the new function graph with codes borrowed from above.

# %% [markdown]
# # One answer to Exersice 1. (only expand this after you have made an attempt to the exercise)

# %%
def TheCoolestFunctionByXYi(x):
  return np.sin(Relu_SecondImpementation(x))

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = TheCoolestFunctionByXYi(x)
plt.plot(x,y)
plt.show()
