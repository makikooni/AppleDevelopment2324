# %% [markdown]
# <a href="https://colab.research.google.com/github/makikooni/appleDevelopment2324/blob/main/ML_One.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
#
# This notebook contains colab notebook basics (how to use) and python basics (data types, print, list and loop).
#
#
# Referenced from ECS7022P: Computational Creativity from Queen Mary University of London, School of Electronic Engineering and Computer Science.
# Original Author: Simon Colton with original help from Raluca Gaina.
# Modified by Xiaowan Yi.
#
# ---
#
# # **Practical 1. Python Programming in Colab Notebooks!**
#
# In this practical, you will be guided through the basics of python programming within the Colab Notebooks environment. Colab notebooks are a great, free, environment offered by Google which are particularly useful for deep learning. For today's practical session, you're encouraged to play around, break things, and learn how it all works. Please study each of the cells of code, especially the code comments and make sure you understand exactly how things are working before proceeding. If you don't understand, please ask me to explain. If you get through the notebook during the session, please check out the notebooks linked at the bottom - choose ones which are of most interest to you.
#
# Please turn on "Menu" => "View" => "Table of Contents" to navigate this notebook.
#
# ---

# %% [markdown]
# # Copying Notebooks
#
# * Don't worry if Google points out that this is not one of their own notebooks - this notebook is safe!
#
# The first thing to do is to make a copy of this notebook and save it to your GDrive. If you haven't yet set up a Google account, you will need to do this. To make a copy, use the File Menu and choose the "Save a copy in GDrive" option. When you have made a copy, open that copy and close this one. You will now be able to edit your own copy, and keep the edits. If you want to start a notebook from scratch, there is a "New Notebook" option from the File menu.

# %% [markdown]
# <a name="programming_in_cells"></a>
# # Programming in Cells
#
# In Colab notebooks (which are basically Jupyter notebooks), we add and run python code in cells. There are also text cells (like this one), but they cannot have code in them. The following notes are important to understand:
#
# * Code and text (simple Markdown/HTML support) are split into cells that can be run individually. Cells can be thought of as functions, grouping together a block of code. The flow through the program can be automatic from top to bottom, or manually controlled (by running cells in the desired order).
# * All cells are connected, e.g. import statements can all be done in one cell, and subsequent (and previous) cells can use the packages imported.
# * A cell must be executed for its contents to take effect (e.g. for files to be imported, variable values set etc.)
# * Cells have individual output, which can be text, images, interactive widgets etc.
# * Parameters for the code can be set, and code hidden, so that the notebook displays an interactive and easy to use application with no coding required (for your users).
#
# Programming in cells can be a little disorienting to start with. It's important to remember that the RAM memory that holds your program's state is preserved from cell to cell. So, if you set a variable in one cell, that variable will still be set in the next cell, even if you delete the original cell.

# %%
my_first_var = 5
print(my_first_var)
# Out:
# 5

# %%
"""
Here is our first code cell. Note that we're programming in python, so we
can add comments inbetween the three-quotes lines, or comment out a single
line with a #. Note that - bizarrely - if you use three quotes comments at the
bottom of a cell, the text is printed to the output.

Click on the play button at the top left of this cell, or press CTRL+Enter
(CMD+Enter on a Mac) to run the following two lines of code in this cell.
After you've clicked on play button, the output appears in the bottom part
of this cell - have a look for it appearing.
"""



#Here we are creating a variable named "a" and assigning value 5 to a variable
a = 5
#xyi note: btw this is how you define a variable in python, no "var" no type specification compared to swift

# Here we are using the python built-in method print() to print stuff to the output
print(a)
#python will infer variable's type during runtime, type() is python's built-in function to examine type
print(type(a))

# Note that after you've run it, a little green tick appears next to the play
# button and it also tells you how long it took for the cell to run. When the
# cell is edited, the tick goes away and you know that you may have to run
# it again.

# Note also that you can use Shift+ENTER to run and move to the next cell and
# Alt/Option+ENTER to run this cell and create a new code cell following
# (useful for development). Try them out!

# each line that is printed out below corresponds to one print() call from above
# for instance, the first line from the output below which is "5" corresponds to "print(a)" from above

# %%
# note that this cell's a is the same variable as previous cell's
# as long as they have the same variable name, (which is a in this case),
# they are the same variable we are referring to regardless of being located in different cells
# think of one colab note book as one BIG swift file where the cells' boundaries no longer exist
a = 10.0
print(a)
print(type(a))

# %%
# becuase of dynamic typing, we can change the value of a to another integer, or even another type!
a = "this is my awesome string"
print(a)
print(type(a))

# %% [markdown]
# This is the end of week 4.|

# %% [markdown]
# <a name="define_a_function"></a>
# # Define a function (week 5)

# %%
# To define a function, use the python "def" keyword, as below. Click on play
# to load this function into memory.


def show_powers(a, b):
  for i in range(0, b):
    print(a**i) # Note that x ** y calculates x to the power y.

# Note that there is no output, because we've not actually run the function,
# we've only defined it.

#xyi note: see how this function defition is compared to swift?
#no need to specify parameter types and return types
#may i suggest adding some comments to inform yourself what are the desired in/out parameter types
#or actually don't, we lazy python users :)

#like:
def show_powers(a, b):
  #a and b should be some numbers, int, float, not list etc.
  for i in range(0, b):
    print(a**i)
    #output should be numbers (float most likely

# %%
# Now we can run the function in this cell:

show_powers(8, 10)
# Out:
# 1
# 8
# 64
# 512
# 4096
# 32768
# 262144
# 2097152
# 16777216
# 134217728

# %%
# of course we should be more punk and rebellious, try running this

show_powers("hello", 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b53f4da115ab> in <module>
#       1 # try running this
#       2
# ----> 3 show_powers("hello", 10)
#
# <ipython-input-1-ad4e1a46340e> in show_powers(a, b)
#      18   #a and b should be some numbers, int, float, anything, not list etc.
#      19   for i in range(0, b):
# ---> 20     print(a**i) # Note that x ** y calculates x to the power y.
#      21     #output should be numbers (float most likely
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
# Watch out when you name your functions, as re-defining a function will
# override the original one, like here:

def show_powers(a, b):
  for i in reversed(range(0, b)):
    print(a**i)

show_powers(17, 10)

# Unless you run the cell with the previous definition of show_powers in it,
# that version of the function will be lost forever. It's important to keep
# track of functions and use different names for different functions. Try
# running the cell above again, and you'll see the output change, which can
# be disorientating.

# %% [markdown]
# <a name="importing_packages"></a>
# # Importing Packages (week 5)
#
# There are thousands of great python code packages to import into your notebook. Once an import statement has been executed, the imported package (or function, class, etc.) will be available in all code cells - including ones higher in the notebook.

# %%
# Here we import Audio and Image classes and a clear_output function
# from the IPython.display package.

from IPython.display import Audio, Image
from IPython.display import clear_output

# Check out the other cells below for different ways of importing and the
# link at the bottom for in-detail discussion of python imports.

# %% [markdown]
# <a name="uploading_files"></a>
# # Uploading files to the Notebook and Viewing Outputs/Media (optional)

# %%
"""
First note that to view a variable, you can simply write it at the bottom
of the cell, which looks weird, but works. After running this cell, the first
time, try moving the "a" line to the top of the code and running again.
"""

print("The value of a is:")
a

# %%
"""
Notebooks can also show images and play music. Run this cell to see how they
are displayed. Note that there are some files available on the hard drive
that Google mounts your runtime on, in the directory: /usr/share.

Note this won't work unless you've played the imports cell.
"""

print(" ")
audio_object = Audio("/usr/share/sounds/freedesktop/stereo/phone-incoming-call.oga")
display(audio_object)
print(" ")
display(Image("/usr/share/backgrounds/brad-huchteman-stone-mountain.jpg"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# A straightforward way to get a file from the internet to use in a notebook
# is to use the wget command. Note that this is an operating system call,
# rather than python, so we put a ! sign at the start.

# !wget http://www.imaginative.ai/art/videos/ganlapse/glasshouse.mp4

# This downloads the file glasshouse.mp4 (from Simon Colton's Ganlapse series
# at imaginative.ai). Have a look in your files (click the icon on the left) to
# check that glasshouse.mp4 has arrived.

clear_output()

# %%
# Displaying videos isn't straightforward as IPython.display.Video doesn't seem
# to work. But here is a way of getting a video to play using ipywidgets.
# Note that this takes a while to process the video - please be patient!
# (This worked using Colab within Chrome on a Macbook, but because of video
# codecs, it may not work on your setup). Note also that it's fine to have import
# statements in any cell you want, like here.

from ipywidgets import Video
video = Video.from_file("glasshouse.mp4", play="True")
display(video)

# %% [markdown]
# <a name="keeping_things_tidy"></a>
# # Keeping Things Tidy (Optional)

# %%
"""
To keep your notebook tidy, you can then click on the icon on the left of
the output, to clear all the output. Play this cell, then try clearing the output.
"""

b = max(10, 12, 17)
print(b)

# %%
# You can also use the clear_output function that we imported above. This can
# be useful to clear away junk that is left after installing packages. Add a
# clear_output() line to the code below and run it.

for i in range(1, 1000):
  print(i)

# Note that by default, output from a cell is saved with the notebook, so
# you will see it when you open the notebook next time, and it might be better
# to clear the output of some (or all) cells before sharing your notebook.

# %%
#@title Click on to "Show Code" to, erm, show the code here

"""
If you want to hide the code entirely in a cell, you can give it a title, as
we've done above with #@title. Then you can right-click the cell and choose
form -> hide code.
"""
print("The code here has been hidden.")

# %% [markdown]
# <a name="adding_form_elements"></a>
# # Adding Form Elements (Optional)
#
# The cell below hides quite a bit of code to calculate refactorable numbers (which are integers such that the number of divisors is itself a divisor, e.g., 9 has three divisors, 1, 3 and 9, and three divides 9). By giving the cell a #@title, you can hide the code. In addition by using the #@param tag after the initial declaration of a variable, you can expose that variable in a form for users. This helps to make notebooks more accessible and less scary for users! In this example, there are integers, string choices and a boolean check box exposed, as well as a numerical slider.

# %%
#@title Refactorable Numbers

upper_bound = 10000 #@param
start_digit = "5" #@param ["Any", "1", "2", "3", "4", "5", "6", "7", "8", "9"]
must_be_odd_number = False #@param {type:"boolean"}
min_num_divisors = 17 #@param {type:"slider", min:1, max:100, step:1}

# Code for tau (number of divisors of an integer) from:
# https://rosettacode.org/wiki/Tau_function#Python

def tau(n):
    assert(isinstance(n, int) and 0 < n)
    ans, i, j = 0, 1, 1
    while i*i <= n:
        if 0 == n%i:
            ans += 1
            j = n//i
            if j != i:
                ans += 1
        i += 1
    return ans

# Note that the for loop goes to upper + 1
def show_refactorables(upper, first_digit, odd_only, min_divisors):
  for i in range(1, upper + 1):
    t = tau(i)
    if t >= min_num_divisors and (i % t) == 0:
      if not odd_only or i % 2 == 1:
        if first_digit == "Any":
          print(i)
        elif f"{i}"[0] == first_digit:
          print(i)

show_refactorables(upper_bound, start_digit, must_be_odd_number, min_num_divisors)

# %% [markdown]
# <a name="connecting_to_your_gdrive"></a>
# # Connecting to your GDrive (Optional)
#
# A good place to save models you have trained, or checkpoints, or output artefacts is on your GDrive. To do that you need to mount the GDrive. This can be done within the Colab GUI, by clicking on the files folder on the left hand side, then clicking on the GDrive and agreeing to mount it. Try doing that now. It will mount the drive to a folder called "drive/MyDrive", into which you can write files and read them.

# %%
# An alternative way is to use code to mount the drive, as follows:

from google.colab import drive
drive.mount('drive')

# This is a bit more painful however. Don't click this cell if you have already
# mounted your GDrive.

# %%
# Once you have connected your GDrive, you can save files to it. Here is an
# example of writing a text file to your GDrive.

with open("drive/MyDrive/delete_me_later.txt", "w") as f:
  for i in range(0, 1000):
    f.write(f"{i}")

# Check your GDrive to see if this file has arrived. Note that there is a
# "refresh" option for a directory (use right-click), which is handy.

# %%
# Keeping files on your GDrive is a good idea, as notebooks have quick and easy
# access to the GDrive. However, sometimes you might want to download a file.
# You can do this with:

from google.colab import files
files.download("drive/MyDrive/delete_me_later.txt")

# This should download straight to your downloads folder - check to see.

# Don't forget to delete the file now, as it's pointless! To do this, open the files
# view with the icon on the left hand side. Then navigate to the file in
# drive/MyDrive, right click it (or click its three dots icon), and choose delete.

# %% [markdown]
# <a name="sharing_your_notebook"></a>
# # Sharing your Notebook
#
# Colab notebooks are an important part of the open source movement and there are thousands of freely available notebooks you can find (including some listed at the bottom of this notebook). To make your own notebook available, click on the "Share" icon at the top of the notebook. Then you can choose to share it with only selected people or make it available to anyone who has the link (that's what I did for this notebook).
#
# Note that you must make the notebook for your assessed project publicly available so that we can run it, when marking your work.

# %% [markdown]
# <a name="adding_a_gui"></a>
# # Adding a Graphical User Interface (GUI) (Optional)
#
# While Colab notebooks enable you to have marked up text, to show media and have simple forms, this is quite limited, and you may want to implement a more sophisticated GUI. One way to do this is to use the ipywidgets package, as we do here. Another way is to use Gradio, which has the advantage that you may be able to publish your work as a HuggingFace Space.

# %%
# This cell has some helper functions which enable us to generate GUI widgets.
# For buttons, it enables us to attach a function name so that when the button
# is pressed, the function is called

import ipywidgets

def get_button(desc, on_click):
  button = ipywidgets.widgets.Button(description=desc)
  button.on_click(on_click)
  return button

def get_slider(desc, min, val, max):
  return ipywidgets.widgets.IntSlider(value=val, min=min, max=max, step=1,
    description=desc, disabled=False, continuous_update=False,
    orientation='horizontal', readout=True, readout_format='d')

def get_text_box(desc, value="", default="Blank"):
  return ipywidgets.widgets.Text(value=value, placeholder=default, description=desc, disabled=False)

def get_dropdown_list(desc, options, val=None):
  v = options[0] if val == None else val
  return ipywidgets.widgets.Dropdown(options=options, value=v, description=desc, disabled=False)

def get_label(value):
  return ipywidgets.widgets.Label(value=value)

def get_check_box(description, value):
  return ipywidgets.widgets.Checkbox(value=value, description=description, disabled=False, indent=False)

# %%
# Here is an example GUI. Note that you need to have already played the
# cell for refactorable numbers, as this loads the tau(n) function.

# Note that the function being called on the button click is passed a pointer
# to the button, from which you can get the button's text. Try playing around
# with this to understand it. Also check out the documentation for ipywidgets
# in the link given at the bottom of this notebook.

# Note also that you can change the slider and click the button as many times
# as you like. Re-playing the cell only re-loads the GUI.

# SETTING UP THE THREE WIDGETS IN THE GUI
prime_label = get_label("")

def button_clicked_function(b):
  # You can use b.description to determine the button that's been clicked
  prime_label.value = "IS A PRIME" if tau(slider.value) == 2 else "IS NOT A PRIME"

button = get_button("CHECK PRIME", button_clicked_function)
slider = get_slider("Integer", 1, 17, 100)

# DISPLAYING A HELPER LABEL
display(get_label("Choose an integer and click the button to see if it's prime."))

# LAYING OUT THE WIDGETS HORIZONTALLY
box_layout = ipywidgets.Layout(display='flex', flex_flow='row',
                               align_items='stretch', width='70%')
box = ipywidgets.Box(children=[button, slider, prime_label], layout=box_layout)

# SHOWING THE GUI ON SCREEN
display(box)
# Out:
# Label(value="Choose an integer and click the button to see if it's prime.")
# Box(children=(Button(description='CHECK PRIME', style=ButtonStyle()), IntSlider(value=17, continuous_update=Fa…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b2a5590923d0> in button_clicked_function(b)
#      15 def button_clicked_function(b):
#      16   # You can use b.description to determine the button that's been clicked
# ---> 17   prime_label.value = "IS A PRIME" if tau(slider.value) == 2 else "IS NOT A PRIME"
#      18
#      19 button = get_button("CHECK PRIME", button_clicked_function)
#
# NameError: name 'tau' is not defined

# %% [markdown]
# <a name="connecting_to_a_gpu"></a>
# # Connecting to a GPU
#
# Most deep learning models are quicker to train and deploy if you use a GPU, rather than a CPU. One of the benefits of Colab notebooks is the free availability (albeit limited) of GPUs. To enable your code to run on a GPU, use the "Runtime" menu to choose "Change runtime type", and from the dialog box, choose a GPU. Note that this will necessarily restart your runtime and you will lose everything (functions, variables, classes) currently in memory. There are a number of limitations to using Colab notebooks (see below), and it is **much** better if you can develop your notebook on a CPU, using GPUs sparingly.
#
# **IMPORTANT**
#
# After you have tried the GPU, go back to the CPU. This will delete everything from memory, so you will have to go back and click on play for all the cells (as some of the functions are required later).

# %%
# Use the above instructions to connect to a GPU, then run this code to list the physical
# devices that are available. Then disconnect the GPU and run this cell again, to see
# what has changed. Note this is the first (but not the last) time you'll use
# Tensorflow!

import tensorflow as tf

print("TF version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices("GPU"))

# This command can be useful to monitor what's going on with your GPU.
! nvidia-smi

# %% [markdown]
# <a name="colab_limitations"></a>
# # Colab Limitations
#
# Colab is a great free resource, but it does have limitations that may be frustrating, especially as time gets tight for a deadline. This is because you may get locked out of runtimes, i.e., you can't run your colab notebook (although you can edit it). This happens if you run a process for a long time (12+ hours), or if it detects a long period of inactivity. You will eventually be let back onto the runtimes, but it could be quite a while to wait.
#
# So, the best advice is to:
#
# * Try and develop using a CPU runtime as much as possible, only using a GPU when necessary.
#
# * When you have finished in a session, always use the "Runtime" menu to "Disconnect and delete runtime".
#
# * If you are undertaking a big calculation, like training a neural model, always save your work (e.g., model checkpoints) at regular intervals, so you don't have to start from the beginning if you are thrown out of the runtime.
#
# Note that it is possible to purchase Colab pro for $9.99 per month, which gains you 100 compute units. Running any process on the CPU uses around 0.1 units per hour. Running any process on the GPU uses around 2 units per hour. Note that even if you are not actually runnning any code on the GPU, if you are connected, then this is using that GPU and it counts against your compute units.

# %% [markdown]
# <a name="python_classes"></a>
# # Python Classes (Optional)
#
# Object oriented programming is a good way to implement large code bases, and python allows this. In the following, we have a simple class with variables and methods set up. Note that you have to be very careful with the scoping of variable with classes - try and understand this example in that respect.

# %%
# Here is the code for the ComputationalCreativity class. Note that all the
# function definitions should have first variable as "self", unless they are
# meant to be static.

class ComputationalCreativity:

  # Note that you can use a default value for inputs (to initiators like
  # this, byt also to any function def). Here the default is "You're the best"
  # for the motivational slogan variable.

  def __init__(self, motivational_slogan="You're the best"):
    self.motivational_slogan = motivational_slogan

  def show_me_the_slogan(self):
    print(self.motivational_slogan)

  def change_that_variable(self):
    # global variable_to_change
    variable_to_change = "HAS BEEN CHANGED NOW"

  def this_is_a_static_method(val_to_square):
    return val_to_square * val_to_square

cc = ComputationalCreativity("The best module in the whole wide world!")
cc.show_me_the_slogan()

# We can change the object's variable externally
cc.motivational_slogan = "Ain't that right."
cc.show_me_the_slogan()

# But the class cannot change a global variable, given the scope
variable_to_change = "NOT BEEN CHANGED YET"
cc.change_that_variable()

# To get it to change the "variable_to_change" variable, you need to identify
# that this is a global variable, by adding the line

# global variable_to_change

# to the top of the change_that_variable function in the class. Try it and see
# by running the cell again.

print(variable_to_change)

# Static methods can be called like this:

print(ComputationalCreativity.this_is_a_static_method(17))

# %%
"""
Note that if you only want a class to hold data in (i.e., with no methods to
be called), you may be better off with a @dataclass, like this one below. These
can be instantiated in the same way as a normal class.
"""

from dataclasses import dataclass

@dataclass
class CCDataclass:
  motivational_slogan: "Fabuloso"
  number_of_students: int
  scores_dict: None
  is_the_best_module: bool

ccd = CCDataclass("Simply no better", 117, {"Frank": 97, "Georgina": "99"}, True)
print(ccd)

# %% [markdown]
# <a name="python_reflection"></a>
# # Python Reflection (Optional)
#
# Python has some abilities to inspect and generate code at runtime, which can be really useful. Make sure that you have run the ComputationalCreativity class cell above, and then run this one. Try and work out what is happening here.

# %%
# The in-built dir static function gives you the names of variables and methods
# in a class.

# Note the use of the filter here (see hints and tips below)
obj = ComputationalCreativity("Startlingly good")
var_names = dir(obj)
print(var_names)
my_names = filter(lambda n: "__" not in n, var_names)
print(list(my_names))

# The class built-in static function can create a class from its name
klass = globals()["ComputationalCreativity"]
cc_obj = klass("Supremely brilliant")
print(cc_obj.motivational_slogan)

# And we can set attributes as well, using the setattr function
setattr(cc_obj, "motivational_slogan", "Now set with setattr")
print(cc_obj.motivational_slogan)

# And we can get the attribute using the getattr function:
print(getattr(cc_obj, "motivational_slogan"))

# %% [markdown]
# <a name="python_pitfalls_to_avoid"></a>
# # Python Pitfalls to Avoid!

# %%
# Python allows you to use non-existent functions, like "exp" below. This cell will
# run with no problems, and look as if everything is OK. Add a line:

# show_powers(10, 10)

# to the bottom of the cell, and re-run to see what the issue is.

def show_powers(a, b):
  for i in range(0, b):
    print(exp(a, b))

# Always check the cell text editor to see if a function has a wavy line underneath it.
# Try to resolve all the issues before running the code.

# Note that the error messages can be clicked to find the place where the bug
# happened.

# %%
# Python is not compiled, but interpreted line by line. It will happily let you
# run a time (and energy) consuming cell which has a fatal error at the end of
# it. This is why, if you're training models over a number of hours, you should
# always save checkpoints. Try this code and see if you can fix it, but only
# after you've wasted time/energy due to a typing error! Watch out for the
# green arrow which points to the line of the code which is currently running.

# Calculating the sum of squares between 0 and 100 million.
import time
start_time = time.perf_counter()
total = 0
for i in range(0, 100000000):
  total += i * i
end_time = time.perf_counter()
time_wasted = (end_time - start_time) # the // takes the floor
print(f"You just wasted {time_wasted:.0f} seconds because of a typo!")
print("Here is the total:")
print(tOtal)

# Again - check for annoying typos in the cell text editor before running.
# And use the hyperlinks in the error messages to pinpoint the issue.

# %%
# Python does not have typing, like most grown up programming langauges. This means
# you can make wonderfully terrible code which is almost impossible to maintain. Python
# is also happy for you to re-assign an input variable, which can be mighty confusing.

# The code below will fail 50% of the time because the output from the function
# could be either a string or an int. While this example doesn't look bad, in
# more complicated code, it's easy to completely lose sight of what kind of
# object a variable is actually pointing to!

def what_type_is_v(v):
  v = "a string" if random.randint(0, 1) == 1 else -17
  return v

v = what_type_is_v(10)
print(v + 10)

# Repeatedly run this cell to see it fail sometimes. This is an intermittent
# bug (the worst type) which python allows to be easily coded into programs.

# %%
# OK, try and work out what the output from this cell will be before running it!
# And if you can work out what's output, then see if you know what type it is.

# People put awful code like this into colabs all the time! BEWARE!

def ive_seen_this_kind_of_thing_a_lot_too(val):
  val = val + (val // 5)
  val = f"{val}.{val}"
  val = float(float(val) // 3)
  return f"{val}"

val = 100
val = ive_seen_this_kind_of_thing_a_lot_too(val)
print(val)

# Now try changing val to a float: 100.17, and run it again

# %% [markdown]
# <a name="python_hints_and_tips"></a>
# # Python hints and tips
#
# Here are a few things that could make python programming less annoying. In all of these, please try and work out what is happening, and ask if you don't understand. Make sure you've run the cell called "Adding Form Elements" above.

# %%
# Formatting Numbers as Strings
# Note how we can limit the number of decimal places with the .3f statement

print("Formatting Numbers as Strings")
val = 0.23872634
s = f"The value of val is: {val:.3f}"
print(s + "\nAnd we can add strings together")

# Array Access
# Try and work out what's going on here with the different ways indexing arrays

print("\nArray Access")
arr = list(range(1, 1717)) # Easier to work with lists than ranges
print("arr[0] =", arr[0])
print("arr[-1] =", arr[-1])
print("arr[10:20] =", arr[10:20])
print("arr[1707:] =", arr[1707:])
print("arr[-10:] =", arr[-10:])
print("arr[-10:-5] =", arr[-10:-5])

# Substrings
# Strings can be accessed as if they are arrays of letters, which is nice

print("\nSubstrings")
# Check for existence of a substring
print("si in simon is", "si" in "simon")
# Extracting substrings
print("middle bit of simon is:", "simon"[2:4])

# Enumeration
# It's handy to have a pointer to the index as you iterate over a list.

print("\nEnumeration")
l = ["one", "two", "three", "four", "five"]
for num in l:
  print(num)
print("---")
for ind, num in enumerate(l):
  print(ind, num)

# Dictionaries
# Very handy for storage, basically a hashtable. Use keys() to get the keys

print("\nDictionaries")
dict1 = {'England': 'London', 'France': 'Paris', 'Spain': 'Madrid'}
print(f"{dict1['England']} is the capital of England")
print(list(dict1.keys()))

dict2 = {}
dict2['Australia'] = "Sydney"
print(dict2)

# List Construction
# This is a neat way to construct lists

print("\nList Construction")
squares = [i*i for i in range(0, 10)]
print("squares = ", squares)

# Sorting
# Handy for finding the best generated artefacts

print("\nSorting")
reversed_squares = sorted(squares, reverse=True) # Makes a new list
squares.sort(reverse=True) # Sorts the list in place
print("reversed_squares =", reversed_squares)
print("squares after sort =", squares)

# Sorting a list of objects

print("\nSorting a list of objects")
class ToSort:
  def __init__(self, val):
    self.val = val

clist = [ToSort(19), ToSort(7), ToSort(3), ToSort(189)]
sorted_clist = sorted(clist, key=lambda x: x.val)
print("original clist vals are:", [x.val for x in clist])
print("sorted_clist vals are:", [x.val for x in sorted_clist])

# Filters - similar to sorting, and very handy for compact code

print("\nFilters")
names = ["Simon", "Brad", "Angelina", "Brian", "Brione", "Brangelina"]
print("Names with Br in:", list(filter(lambda n: "Br" in n, names)))

ints = list(range(1, 1717))
refactorables = list(filter(lambda n: n % tau(n) == 0, ints))
print("refactorables =", refactorables)

# Compact Conditionals
# Kind of awkward, but works fine (try changing < to >)

print("\nCompact Conditionals")
check = 190 if 10 < 20 else 200
print("check =", check)

# Randomness
# The easiest way to get randomness is to use the random package

print("\nRandomness")
import random
# Note inclusivity of both end points (unlike with ranges)
options = ["optionA", "optionB", "optionC", "optionD"]
print("random.randint(0, 17) =", random.randint(0, 17))
print("random.choice(options) =", random.choice(options))
print("random.uniform(17.17, 17.1717) =", random.uniform(17.17, 17.1717))
print("bool(random.choice([True, False]) =", bool(random.choice([True, False])))

# %% [markdown]
# <a name="to_explore_further"></a>
#
# ---
#
# # To Explore Further
#
# Please visit these notebooks and websites to learn in more detail about using python in colab notebooks. In each case, it's a good idea to try out code yourself in a new notebook, to really understand what is going on.
#
# * A general introduction to Colab notebooks:<br>
# https://colab.research.google.com/notebooks/intro.ipynb
#
# * Introduction to forms with Colab notebooks:<br>
# https://colab.research.google.com/notebooks/forms.ipynb
#
# * Guide to Colab markdown (formatting cells):<br>
# https://colab.research.google.com/notebooks/markdown_guide.ipynb
#
# * Connecting Colab notebooks to github:<br>
# https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb
#
# * Introduction to Tensorflow GPU programming:<br>
# https://colab.research.google.com/notebooks/gpu.ipynb
#
# * Ipywidgets documentation:<br>
# https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20Basics.html
#
# * Using the ipywidgets interact package:<br>
# https://colab.research.google.com/github/jupyter-widgets/ipywidgets/blob/master/docs/source/examples/Using%20Interact.ipynb
#
# * Integrating ipywidgets and the panda package:<br>
# https://colab.research.google.com/github/ahmadkhan242/jupyter_widgets/blob/main/jupyter_widgets.ipynb
#
# * Python imports explained in detail:<br>
# https://realpython.com/python-import/
#
# * More details about Python reflection:<br>
# https://betterprogramming.pub/python-reflection-and-introspection-97b348be54d8
#
# * An introduction to Python classes:<br>
# https://towardsdatascience.com/introduction-to-python-classes-da526ff745df
#
# * Python filters:<br>
# https://realpython.com/python-filter-function/
#
# * A very cool notebook by Berker Banar showcasing Gradio for image-2-audio generation:<br>
# https://colab.research.google.com/drive/16Zf6vMZFlXClnsYYMBZXEokiWX4dHbtl?usp=share_link
#
# * And it's available as a HuggingFace Space too:<br>
# https://huggingface.co/spaces/AnonymousForSubmission/Graphic_Score_and_Audio
#
# ---
